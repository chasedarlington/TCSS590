# %% [markdown]
# <a href="https://colab.research.google.com/github/chasedarlington/TCSS590/blob/HW1/TCSS590_SP26_HW1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # TCSS590-SP26 HW1: Supervised Learning of Behaviors
#
# Starter-only Google Colab companion for **TCSS590-SP26: Theory and Algorithms of Reinforcement Learning, Homework 1**.
#
# This notebook sets up the runtime, loads the starter repository, downloads expert data if needed, and provides run cells for behavior cloning, DAgger, and autoregressive-policy experiments. It intentionally does **not** fill in the assignment TODOs or include solution code.

# %% [markdown]
# ## Runtime setup
#
# Use **Runtime -> Change runtime type -> T4 GPU** when available. CPU can run smoke tests, but the full experiments may be slow. Run cells in order. If Colab asks you to restart after installing packages, restart and rerun from the install cell.

# %%
import sys, platform
print('Python:', sys.version)
print('Platform:', platform.platform())
# Out:
# Python: 3.12.13 (main, Mar  4 2026, 09:23:07) [GCC 11.4.0]
# Platform: Linux-6.6.113+-x86_64-with-glibc2.35

# %% [markdown]
# ## Install dependencies
#
# The repository uses `environment.yml` for conda. In Colab, this cell installs the corresponding pip packages. Colab usually already includes PyTorch, so PyTorch is installed only if missing.

# %%
import importlib.util
import subprocess
import sys

packages = [
    'numpy',
    'matplotlib',
    'gymnasium',
    'gymnasium-robotics',
    'mujoco',
]

subprocess.check_call([sys.executable, '-m', 'pip', 'install', '-q', *packages])

if importlib.util.find_spec('torch') is None:
    subprocess.check_call([
        sys.executable, '-m', 'pip', 'install', '-q',
        'torch', 'torchvision', 'torchaudio'
    ])

import numpy as np
import matplotlib.pyplot as plt
import gymnasium as gym
import mujoco
import torch

print('numpy:', np.__version__)
print('gymnasium:', gym.__version__)
print('mujoco:', mujoco.__version__)
print('torch:', torch.__version__)
print('CUDA available:', torch.cuda.is_available())
if torch.cuda.is_available():
    print('GPU:', torch.cuda.get_device_name(0))
# Out:
# numpy: 2.0.2
# gymnasium: 1.3.0
# mujoco: 3.8.0
# torch: 2.10.0+cu128
# CUDA available: True
# GPU: Tesla T4

# %% [markdown]
# ## Load the starter project
#
# After the public GitHub repository is created, leave `USE_GITHUB = True`. Before publication, set `USE_GITHUB = False` and upload the starter zip through the Colab file picker.

# %%
from pathlib import Path
import os
import shutil
import subprocess
import zipfile

USE_GITHUB = True
REPO_URL = 'https://github.com/liuxt/tcss590-rl-coding-assignment-1.git'
REPO_DIR = Path('/content/tcss590-rl-coding-assignment-1')

if USE_GITHUB:
    if REPO_DIR.exists():
        shutil.rmtree(REPO_DIR)
    subprocess.check_call(['git', 'clone', '--depth', '1', REPO_URL, str(REPO_DIR)])
else:
    from google.colab import files
    uploaded = files.upload()
    zip_names = [name for name in uploaded if name.endswith('.zip')]
    if not zip_names:
        raise RuntimeError('Upload a .zip file containing the starter repository.')
    zip_path = Path('/content') / zip_names[0]
    if REPO_DIR.exists():
        shutil.rmtree(REPO_DIR)
    with zipfile.ZipFile(zip_path, 'r') as zf:
        zf.extractall('/content')

    if not REPO_DIR.exists():
        candidates = [
            Path('/content/tcss590-rl-coding-assignment-1-starter'),
            *[p for p in Path('/content').iterdir() if p.is_dir() and p.name.startswith('tcss590-rl-coding-assignment-1')],
        ]
        candidates = [p for p in candidates if p.exists()]
        if not candidates:
            raise FileNotFoundError('Could not find the extracted starter repository folder.')
        shutil.move(str(candidates[0]), str(REPO_DIR))

os.chdir(REPO_DIR)
print('Working directory:', Path.cwd())
# Out:
# Working directory: /content/tcss590-rl-coding-assignment-1

# %% [markdown]
# ## Verify starter files
#
# This checks the project structure only. It does not check whether the TODOs have been completed.

# %%
from pathlib import Path

required_files = [
    'main.py', 'bc.py', 'dagger.py', 'utils.py', 'evaluate.py',
    'environment.yml', 'policy.py', 'scripts/download_data.sh'
]
optional_files = ['run_experiments.py', 'TCSS590_SP26_HW1.ipynb']
missing = [f for f in required_files if not Path(f).exists()]
if missing:
    raise FileNotFoundError('Missing required starter files: ' + ', '.join(missing))
print('Required starter files are present.')
for f in optional_files:
    print(f'{f}:', 'present' if Path(f).exists() else 'not present')
# Out:
# Required starter files are present.
# run_experiments.py: present
# TCSS590_SP26_HW1.ipynb: present

# %% [markdown]
# ## Download expert data
#
# The public starter repository should not commit the large `.pkl` files. This cell downloads them into `data/` if they are missing.

# %%
from pathlib import Path
import subprocess

required_data = [
    Path('data/reacher_expert_data.pkl'),
    Path('data/reacher_expert_policy.pkl'),
    Path('data/pointmaze_expert_data.pkl'),
]
missing_data = [p for p in required_data if not p.exists()]
if missing_data:
    print('Missing data files:', [str(p) for p in missing_data])
    subprocess.check_call(['bash', 'scripts/download_data.sh'])
else:
    print('Expert data files are already present.')

for p in required_data:
    if not p.exists():
        raise FileNotFoundError(p)
    print(f'{p}: {p.stat().st_size / (1024 * 1024):.2f} MB')
# Out:
# Missing data files: ['data/reacher_expert_data.pkl', 'data/reacher_expert_policy.pkl', 'data/pointmaze_expert_data.pkl']
# data/reacher_expert_data.pkl: 0.05 MB
# data/reacher_expert_policy.pkl: 0.27 MB
# data/pointmaze_expert_data.pkl: 36.22 MB

# %% [markdown]
# ## Quick import smoke test
#
# This verifies that the local modules and environments import correctly. It does not complete any assignment TODOs.

# %%
import torch
import gymnasium as gym
from reach_goal.envs.pointmaze_env import PointMazeEnv
from utils import get_expert_data, PolicyGaussian, PolicyAutoRegressiveModel

reacher = gym.make('Reacher-v4')
pointmaze = PointMazeEnv(render_mode='rgb_array')
print('Reacher observation/action shapes:', reacher.observation_space.shape, reacher.action_space.shape)
print('PointMaze observation/action shapes:', pointmaze.observation_space.shape, pointmaze.action_space.shape)
reacher.close(); pointmaze.close()
print('Imports and environment construction succeeded.')
# Out:
# /usr/local/lib/python3.12/dist-packages/gymnasium/envs/registration.py:513: DeprecationWarning: WARN: The environment Reacher-v4 is out of date. You should consider upgrading to version `v5`.
#   logger.deprecation(
# Reacher observation/action shapes: (11,) (2,)
# PointMaze observation/action shapes: (4,) (2,)
# Imports and environment construction succeeded.

# %% [markdown]
# ## Complete the assignment TODOs
#
# Before running the training cells, edit these files in Colab or locally:
#
# - `bc.py`: implement behavior cloning.
# - `dagger.py`: implement DAgger.
# - `utils.py`: implement `PolicyAutoRegressiveModel`.
#
# Colab's file browser can open and edit these files directly. Save your edits before running experiments.

# %% [markdown]
# ## Behavior cloning with Gaussian policy
#
# Run these after implementing the behavior cloning TODOs in `bc.py`.

# %%
# !mkdir -p logs
# !python main.py --env reacher --train behavior_cloning --policy gaussian | tee logs/bc_reacher_gaussian.log
# Out:
# /usr/local/lib/python3.12/dist-packages/gymnasium/envs/registration.py:513: DeprecationWarning: WARN: The environment Reacher-v4 is out of date. You should consider upgrading to version `v5`.
#   logger.deprecation(
# using device cuda
# Imported Expert data successfully
# Traceback (most recent call last):
#   File "/content/tcss590-rl-coding-assignment-1/main.py", line 101, in <module>
#     simulate_policy_bc(env, policy, expert_data, num_epochs=num_epochs, episode_length=episode_length,
#   File "/content/tcss590-rl-coding-assignment-1/bc.py", line 41, in simulate_policy_bc
#     loss.backward()
#     ^^^^^^^^^^^^^
# AttributeError: 'NoneType' object has no attribute 'backward'

# %%
# !mkdir -p logs
# !python -u main.py --env pointmaze --train behavior_cloning --policy gaussian | tee logs/bc_pointmaze_gaussian.log
# Out:
# using device cuda
# Imported Expert data successfully
# [0] loss: -0.21278468
# [1] loss: -1.26538544
# [2] loss: -1.65053802
# [3] loss: -1.89658298
# [4] loss: -2.07685566
# [5] loss: -2.22532149
# [6] loss: -2.35085279
# [7] loss: -2.45171677
# [8] loss: -2.56432861
# [9] loss: -2.65449429
# test 0, success [False], reward 0.0
# test 1, success [False], reward 0.0
# test 2, success [False], reward 0.0
# test 3, success [False], reward 0.0
# test 4, success [False], reward 0.0
# test 5, success [False], reward 0.0
# test 6, success [False], reward 0.0
# test 7, success [False], reward 0.0
# test 8, success [False], reward 0.0
# test 9, success [False], reward 0.0
# test 10, success [ True], reward 1.0
# test 11, success [False], reward 0.0
# test 12, success [False], reward 0.0
# test 13, success [False], reward 0.0
# test 14, success [False], reward 0.0
# test 15, success [False], reward 0.0
# test 16, success [False], reward 0.0
# test 17, success [False], reward 0.0
# test 18, success [False], reward 0.0
# test 19, success [ True], reward 1.0
# test 20, success [False], reward 0.0
# test 21, success [False], reward 0.0
# test 22, success [False], reward 0.0
# test 23, success [False], reward 0.0
# test 24, success [False], reward 0.0
# test 25, success [False], reward 0.0
# test 26, success [False], reward 0.0
# test 27, success [False], reward 0.0
# test 28, success [False], reward 0.0
# test 29, success [ True], reward 1.0
# test 30, success [False], reward 0.0
# test 31, success [False], reward 0.0
# test 32, success [False], reward 0.0
# test 33, success [False], reward 0.0
# test 34, success [False], reward 0.0
# test 35, success [False], reward 0.0
# test 36, success [False], reward 0.0
# test 37, success [False], reward 0.0
# test 38, success [False], reward 0.0
# test 39, success [False], reward 0.0
# test 40, success [False], reward 0.0
# test 41, success [False], reward 0.0
# test 42, success [False], reward 0.0
# test 43, success [ True], reward 1.0
# test 44, success [False], reward 0.0
# test 45, success [False], reward 0.0
# test 46, success [False], reward 0.0
# test 47, success [False], reward 0.0
# test 48, success [False], reward 0.0
# test 49, success [False], reward 0.0
# test 50, success [False], reward 0.0
# test 51, success [False], reward 0.0
# test 52, success [False], reward 0.0
# test 53, success [False], reward 0.0
# test 54, success [False], reward 0.0
# test 55, success [False], reward 0.0
# test 56, success [ True], reward 1.0
# test 57, success [False], reward 0.0
# test 58, success [False], reward 0.0
# test 59, success [False], reward 0.0
# test 60, success [ True], reward 1.0
# test 61, success [ True], reward 1.0
# test 62, success [False], reward 0.0
# test 63, success [False], reward 0.0
# test 64, success [False], reward 0.0
# test 65, success [False], reward 0.0
# test 66, success [ True], reward 1.0
# test 67, success [False], reward 0.0
# test 68, success [False], reward 0.0
# test 69, success [False], reward 0.0
# test 70, success [False], reward 0.0
# test 71, success [False], reward 0.0
# test 72, success [False], reward 0.0
# test 73, success [False], reward 0.0
# test 74, success [False], reward 0.0
# test 75, success [False], reward 0.0
# test 76, success [False], reward 0.0
# test 77, success [False], reward 0.0
# test 78, success [False], reward 0.0
# test 79, success [False], reward 0.0
# test 80, success [ True], reward 1.0
# test 81, success [False], reward 0.0
# test 82, success [False], reward 0.0
# test 83, success [False], reward 0.0
# test 84, success [False], reward 0.0
# test 85, success [False], reward 0.0
# test 86, success [False], reward 0.0
# test 87, success [False], reward 0.0
# test 88, success [ True], reward 1.0
# test 89, success [False], reward 0.0
# test 90, success [ True], reward 1.0
# test 91, success [False], reward 0.0
# test 92, success [False], reward 0.0
# test 93, success [ True], reward 1.0
# test 94, success [False], reward 0.0
# test 95, success [False], reward 0.0
# test 96, success [False], reward 0.0
# test 97, success [ True], reward 1.0
# test 98, success [False], reward 0.0
# test 99, success [False], reward 0.0
# Success rate:  0.13
# Average reward (success only):  1.0
# Average reward (all):  0.13

# %% [markdown]
# ## DAgger with Gaussian policy
#
# Run these after implementing the DAgger TODOs in `dagger.py`.

# %%
# !mkdir -p logs
# !python main.py --env reacher --train dagger --policy gaussian | tee logs/dagger_reacher_gaussian.log
# Out:
# /usr/local/lib/python3.12/dist-packages/gymnasium/envs/registration.py:513: DeprecationWarning: WARN: The environment Reacher-v4 is out of date. You should consider upgrading to version `v5`.
#   logger.deprecation(
# using device cuda
# Imported Expert data successfully
# Expert policy loaded
# [1,     7] loss: 10.65923536
# [2,     7] loss: 3.65186729
# [3,     7] loss: -2.34608863
# [4,     7] loss: -0.71912816
# [5,     7] loss: -1.59514005
# [6,     7] loss: -4.85100520
# [7,     7] loss: -5.04181391
# [8,     7] loss: -7.68279999
# [9,     7] loss: -9.41326916
# [10,     7] loss: -11.34759402
# [11,     7] loss: -13.54385841
# [12,     7] loss: -13.75508869
# [13,     7] loss: -5.46316075
# [14,     7] loss: -13.99251211
# [15,     7] loss: -16.36148882
# [16,     7] loss: -17.41201091
# [17,     7] loss: -18.71402287
# [18,     7] loss: -12.30168512
# [19,     7] loss: -14.15155721
# [20,     7] loss: -18.42492580
# [21,     7] loss: -19.76738000
# [22,     7] loss: -21.59695339
# [23,     7] loss: -23.02899122
# [24,     7] loss: -25.29480457
# [25,     7] loss: -26.24829888
# [26,     7] loss: -29.07071304
# [27,     7] loss: -28.82057381
# [28,     7] loss: -25.87755036
# [29,     7] loss: -27.98184991
# [30,     7] loss: -30.04287767
# [31,     7] loss: -30.77239370
# [32,     7] loss: -31.51306057
# [33,     7] loss: -31.48490906
# [34,     7] loss: -33.04416060
# [35,     7] loss: -35.94887304
# [36,     7] loss: -33.04858685
# [37,     7] loss: -33.27559662
# [38,     7] loss: -34.66014385
# [39,     7] loss: -36.36897802
# [40,     7] loss: -36.35863066
# [41,     7] loss: -35.26242065
# [42,     7] loss: -38.58191013
# [43,     7] loss: -36.65435028
# [44,     7] loss: -29.31479621
# [45,     7] loss: -32.52418613
# [46,     7] loss: -35.08699703
# [47,     7] loss: -34.77384567
# [48,     7] loss: -37.25434875
# [49,     7] loss: -24.98405743
# [50,     7] loss: -34.47026730
# Average DAgger return is -10.14009564126862
# [1,    23] loss: 8478.32028157
# [2,    23] loss: 17.54553938
# [3,    23] loss: 13.78547835
# [4,    23] loss: 10.29728840
# [5,    23] loss: 6.39867442
# [6,    23] loss: 4.00076089
# [7,    23] loss: 0.18935736
# [8,    23] loss: -2.96918008
# [9,    23] loss: -4.36742676
# [10,    23] loss: -3.50675032
# [11,    23] loss: -8.37045032
# [12,    23] loss: -10.82503546
# [13,    23] loss: -11.11421168
# test 9, success True, reward -4.411113383304762
# test 10, success True, reward -3.043843873566429
# test 11, success True, reward -2.1319194235283176
# test 12, success True, reward -5.304248966018286
# test 13, success True, reward -3.816104808452515
# test 14, success True, reward -4.914610964716243
# test 15, success True, reward -1.4614041750730886
# test 16, success True, reward -4.504844769194208
# test 17, success True, reward -4.589917712641336
# test 18, success True, reward -3.6097475607974694
# test 19, success True, reward -2.204486063628842
# test 20, success True, reward -1.6014957895921307
# test 21, success True, reward -5.912477807448334
# test 22, success True, reward -4.654418432163413
# test 23, success True, reward -5.210058978073108
# test 24, success True, reward -6.646607913503893
# test 25, success True, reward -3.313439651160251
# test 26, success True, reward -3.674246846840931
# test 27, success True, reward -4.44780963153521
# test 28, success True, reward -1.046202854511765
# test 29, success True, reward -5.221611059572683
# test 30, success True, reward -2.896173140780093
# test 31, success True, reward -2.822332864607659
# test 32, success True, reward -4.097884379349158
# test 33, success True, reward -0.822049398634993
# test 34, success True, reward -1.771033919196929
# test 35, success True, reward -4.154863913714486
# test 36, success True, reward -6.444888639463344
# test 37, success True, reward -5.0048814230068865
# test 38, success True, reward -6.997796573175278
# test 39, success True, reward -7.392886023754279
# test 40, success True, reward -3.4945138146420995
# test 41, success True, reward -3.8149797996811436
# test 42, success True, reward -5.743555923512333
# test 43, success True, reward -3.811668748976031
# test 44, success True, reward -3.3410942797495986
# test 45, success True, reward -3.684439995014559
# test 46, success True, reward -3.1805455211811724
# test 47, success True, reward -4.418040128837364
# test 48, success True, reward -3.5567314536221595
# test 49, success True, reward -1.2547884799132782
# test 50, success True, reward -5.213057934685411
# test 51, success True, reward -7.264208057437251
# test 52, success True, reward -8.93862333294136
# test 53, success True, reward -2.3537820666294125
# test 54, success True, reward -3.6363119749516253
# test 55, success True, reward -1.9704952310485047
# test 56, success True, reward -4.917440697203596
# test 57, success True, reward -3.628390606801826
# test 58, success True, reward -6.648878791072339
# test 59, success True, reward -2.317791262621599
# test 60, success True, reward -4.622325487281319
# test 61, success True, reward -3.199827936412739
# test 62, success True, reward -6.273676119428631
# test 63, success True, reward -1.6069163835293325
# test 64, success True, reward -2.457895881354849
# test 65, success True, reward -5.557497238211832
# test 66, success True, reward -7.141398842100202
# test 67, success True, reward -4.496375395585491
# test 68, success True, reward -5.063235150082256
# test 69, success True, reward -3.992189494997716
# test 70, success True, reward -3.6116061603564114
# test 71, success True, reward -1.9145682994952151
# test 72, success True, reward -4.052560518141899
# test 73, success True, reward -4.254010328269292
# test 74, success True, reward -7.354081729754926
# test 75, success True, reward -6.245645214263554
# test 76, success True, reward -5.848168589807038
# test 77, success True, reward -4.770903976317981
# test 78, success True, reward -3.8654148135534157
# test 79, success True, reward -5.167700161362
# test 80, success True, reward -6.254837179503604
# test 81, success True, reward -3.8925742230135993
# test 82, success True, reward -3.886356704007972
# test 83, success True, reward -5.059174890388611
# test 84, success True, reward -2.4189677722135
# test 85, success True, reward -2.712244816252287
# test 86, success True, reward -1.0608114760258036
# test 87, success True, reward -4.979321286920333
# test 88, success True, reward -4.364194342762802
# test 89, success True, reward -4.59495700882198
# test 90, success True, reward -5.52661203577227
# test 91, success True, reward -6.343796288814591
# test 92, success True, reward -2.0989550066744638
# test 93, success True, reward -4.405215996642609
# test 94, success True, reward -3.0979580338982213
# test 95, success True, reward -4.502645922167685
# test 96, success True, reward -3.9720902725290657
# test 97, success True, reward -5.99772633468693
# test 98, success True, reward -8.771413154303975
# test 99, success True, reward -5.189068951804998
# Success rate:  1.0
# Average reward (success only):  -4.2448630382123484
# Average reward (all):  -4.2448630382123484

# %%
# !mkdir -p logs
# !python -u main.py --env pointmaze --train dagger --policy gaussian | tee logs/dagger_pointmaze_gaussian.log
# Out:
# using device cuda
# Imported Expert data successfully
# [1,  7355] loss: -11118.56795048
# Average DAgger return is 1.0
# [1,  7388] loss: -7022.35252128
# Average DAgger return is 1.0
# [1,  7429] loss: -9381.23419235
# Average DAgger return is 1.0
# [1,  7449] loss: -11011.49429471
# Average DAgger return is 1.0
# [1,  7466] loss: -11393.51121278
# Average DAgger return is 1.0
# [1,  7483] loss: -11102.96908522
# Average DAgger return is 1.0
# [1,  7501] loss: -11798.94446808
# Average DAgger return is 1.0
# [1,  7524] loss: -12180.46438692
# Average DAgger return is 1.0
# [1,  7540] loss: -13005.41537900
# Average DAgger return is 1.0
# [1,  7559] loss: -13839.81296108
# Average DAgger return is 1.0
# test 0, success [ True], reward 1.0
# test 1, success [ True], reward 1.0
# test 2, success [ True], reward 1.0
# test 3, success [ True], reward 1.0
# test 4, success [ True], reward 1.0
# test 5, success [ True], reward 1.0
# test 6, success [ True], reward 1.0
# test 7, success [ True], reward 1.0
# test 8, success [ True], reward 1.0
# test 9, success [ True], reward 1.0
# test 10, success [False], reward 0.0
# test 11, success [False], reward 0.0
# test 12, success [ True], reward 1.0
# test 13, success [ True], reward 1.0
# test 14, success [ True], reward 1.0
# test 15, success [ True], reward 1.0
# test 16, success [ True], reward 1.0
# test 17, success [False], reward 0.0
# test 18, success [ True], reward 1.0
# test 19, success [ True], reward 1.0
# test 20, success [ True], reward 1.0
# test 21, success [ True], reward 1.0
# test 22, success [ True], reward 1.0
# test 23, success [ True], reward 1.0
# test 24, success [ True], reward 1.0
# test 25, success [False], reward 0.0
# test 26, success [ True], reward 1.0
# test 27, success [ True], reward 1.0
# test 28, success [ True], reward 1.0
# test 29, success [ True], reward 1.0
# test 30, success [ True], reward 1.0
# test 31, success [ True], reward 1.0
# test 32, success [ True], reward 1.0
# test 33, success [False], reward 0.0
# test 34, success [False], reward 0.0
# test 35, success [ True], reward 1.0
# test 36, success [ True], reward 1.0
# test 37, success [ True], reward 1.0
# test 38, success [ True], reward 1.0
# test 39, success [ True], reward 1.0
# test 40, success [ True], reward 1.0
# test 41, success [False], reward 0.0
# test 42, success [ True], reward 1.0
# test 43, success [False], reward 0.0
# test 44, success [ True], reward 1.0
# test 45, success [False], reward 0.0
# test 46, success [ True], reward 1.0
# test 47, success [False], reward 0.0
# test 48, success [ True], reward 1.0
# test 49, success [ True], reward 1.0
# test 50, success [False], reward 0.0
# test 51, success [ True], reward 1.0
# test 52, success [False], reward 0.0
# test 53, success [False], reward 0.0
# test 54, success [ True], reward 1.0
# test 55, success [ True], reward 1.0
# test 56, success [ True], reward 1.0
# test 57, success [False], reward 0.0
# test 58, success [ True], reward 1.0
# test 59, success [ True], reward 1.0
# test 60, success [ True], reward 1.0
# test 61, success [False], reward 0.0
# test 62, success [False], reward 0.0
# test 63, success [ True], reward 1.0
# test 64, success [ True], reward 1.0
# test 65, success [ True], reward 1.0
# test 66, success [False], reward 0.0
# test 67, success [ True], reward 1.0
# test 68, success [False], reward 0.0
# test 69, success [ True], reward 1.0
# test 70, success [ True], reward 1.0
# test 71, success [ True], reward 1.0
# test 72, success [False], reward 0.0
# test 73, success [ True], reward 1.0
# test 74, success [ True], reward 1.0
# test 75, success [ True], reward 1.0
# test 76, success [ True], reward 1.0
# test 77, success [ True], reward 1.0
# test 78, success [ True], reward 1.0
# test 79, success [ True], reward 1.0
# test 80, success [ True], reward 1.0
# test 81, success [False], reward 0.0
# test 82, success [ True], reward 1.0
# test 83, success [ True], reward 1.0
# test 84, success [ True], reward 1.0
# test 85, success [False], reward 0.0
# test 86, success [ True], reward 1.0
# test 87, success [ True], reward 1.0
# test 88, success [ True], reward 1.0
# test 89, success [ True], reward 1.0
# test 90, success [False], reward 0.0
# test 91, success [ True], reward 1.0
# test 92, success [False], reward 0.0
# test 93, success [ True], reward 1.0
# test 94, success [ True], reward 1.0
# test 95, success [ True], reward 1.0
# test 96, success [ True], reward 1.0
# test 97, success [ True], reward 1.0
# test 98, success [ True], reward 1.0
# test 99, success [ True], reward 1.0
# Success rate:  0.77
# Average reward (success only):  1.0
# Average reward (all):  0.77

# %% [markdown]
# ## Autoregressive policies on PointMaze
#
# Run these after implementing `PolicyAutoRegressiveModel` in `utils.py`.

# %%
# !mkdir -p logs
# !python main.py --env pointmaze --train behavior_cloning --policy autoregressive | tee logs/bc_pointmaze_autoregressive.log
# Out:
# using device cuda
# Imported Expert data successfully
# [0] loss: 1.75684273
# [1] loss: 1.18854451
# [2] loss: 1.01184932
# [3] loss: 0.91292703
# [4] loss: 0.84789270
# [5] loss: 0.80125674
# [6] loss: 0.76603653
# [7] loss: 0.73883738
# [8] loss: 0.71683500
# [9] loss: 0.69847415
# test 0, success [ True], reward 1.0
# test 1, success [ True], reward 1.0
# test 2, success [False], reward 0.0
# test 3, success [False], reward 0.0
# test 4, success [ True], reward 1.0
# test 5, success [ True], reward 1.0
# test 6, success [ True], reward 1.0
# test 7, success [ True], reward 1.0
# test 8, success [ True], reward 1.0
# test 9, success [ True], reward 1.0
# test 10, success [False], reward 0.0
# test 11, success [ True], reward 1.0
# test 12, success [ True], reward 1.0
# test 13, success [False], reward 0.0
# test 14, success [ True], reward 1.0
# test 15, success [ True], reward 1.0
# test 16, success [ True], reward 1.0
# test 17, success [ True], reward 1.0
# test 18, success [ True], reward 1.0
# test 19, success [False], reward 0.0
# test 20, success [ True], reward 1.0
# test 21, success [ True], reward 1.0
# test 22, success [False], reward 0.0
# test 23, success [ True], reward 1.0
# test 24, success [False], reward 0.0
# test 25, success [False], reward 0.0
# test 26, success [ True], reward 1.0
# test 27, success [ True], reward 1.0
# test 28, success [ True], reward 1.0
# test 29, success [ True], reward 1.0
# test 30, success [ True], reward 1.0
# test 31, success [False], reward 0.0
# test 32, success [ True], reward 1.0
# test 33, success [ True], reward 1.0
# test 34, success [False], reward 0.0
# test 35, success [False], reward 0.0
# test 36, success [ True], reward 1.0
# test 37, success [False], reward 0.0
# test 38, success [False], reward 0.0
# test 39, success [False], reward 0.0
# test 40, success [False], reward 0.0
# test 41, success [ True], reward 1.0
# test 42, success [ True], reward 1.0
# test 43, success [ True], reward 1.0
# test 44, success [ True], reward 1.0
# test 45, success [False], reward 0.0
# test 46, success [False], reward 0.0
# test 47, success [ True], reward 1.0
# test 48, success [False], reward 0.0
# test 49, success [ True], reward 1.0
# test 50, success [ True], reward 1.0
# test 51, success [False], reward 0.0
# test 52, success [False], reward 0.0
# test 53, success [False], reward 0.0
# test 54, success [ True], reward 1.0
# test 55, success [False], reward 0.0
# test 56, success [False], reward 0.0
# test 57, success [False], reward 0.0
# test 58, success [False], reward 0.0
# test 59, success [ True], reward 1.0
# test 60, success [ True], reward 1.0
# test 61, success [False], reward 0.0
# test 62, success [ True], reward 1.0
# test 63, success [ True], reward 1.0
# test 64, success [False], reward 0.0
# test 65, success [ True], reward 1.0
# test 66, success [False], reward 0.0
# test 67, success [ True], reward 1.0
# test 68, success [ True], reward 1.0
# test 69, success [ True], reward 1.0
# test 70, success [ True], reward 1.0
# test 71, success [ True], reward 1.0
# test 72, success [ True], reward 1.0
# test 73, success [False], reward 0.0
# test 74, success [ True], reward 1.0
# test 75, success [ True], reward 1.0
# test 76, success [False], reward 0.0
# test 77, success [ True], reward 1.0
# test 78, success [ True], reward 1.0
# test 79, success [ True], reward 1.0
# test 80, success [ True], reward 1.0
# test 81, success [ True], reward 1.0
# test 82, success [ True], reward 1.0
# test 83, success [False], reward 0.0
# test 84, success [ True], reward 1.0
# test 85, success [ True], reward 1.0
# test 86, success [ True], reward 1.0
# test 87, success [False], reward 0.0
# test 88, success [False], reward 0.0
# test 89, success [False], reward 0.0
# test 90, success [ True], reward 1.0
# test 91, success [ True], reward 1.0
# test 92, success [False], reward 0.0
# test 93, success [ True], reward 1.0
# test 94, success [ True], reward 1.0
# test 95, success [ True], reward 1.0
# test 96, success [ True], reward 1.0
# test 97, success [False], reward 0.0
# test 98, success [False], reward 0.0
# test 99, success [ True], reward 1.0
# Success rate:  0.63
# Average reward (success only):  1.0
# Average reward (all):  0.63

# %%
# !mkdir -p logs
# !python -u main.py --env pointmaze --train dagger --policy autoregressive | tee logs/dagger_pointmaze_autoregressive.log
# Out:
# using device cuda
# Imported Expert data successfully
# [1,  7355] loss: 7446.24715626
# Average DAgger return is 1.0
# [1,  7415] loss: 5653.22881678
# Traceback (most recent call last):
#   File "/content/tcss590-rl-coding-assignment-1/main.py", line 120, in <module>
#     simulate_policy_dagger(env, policy, expert_data, expert_policy, num_epochs=num_epochs, episode_length=episode_length,
#   File "/content/tcss590-rl-coding-assignment-1/dagger.py", line 67, in simulate_policy_dagger
#     traj = rollout(env, policy, episode_length)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/content/tcss590-rl-coding-assignment-1/utils.py", line 178, in rollout
#     action, _ = agent(o_for_agent) # TODO: May need to convert to numpy
#                 ^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/torch/nn/modules/module.py", line 1776, in _wrapped_call_impl
#     return self._call_impl(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/torch/nn/modules/module.py", line 1787, in _call_impl
#     return forward_call(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/content/tcss590-rl-coding-assignment-1/utils.py", line 115, in forward
#     sample = dist.sample()
#              ^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/torch/distributions/categorical.py", line 147, in sample
#     samples_2d = torch.multinomial(probs_2d, sample_shape.numel(), True).T
#                  ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# KeyboardInterrupt

# %% [markdown]
# ## Optional: run the helper sweep script
#
# The starter repository includes `run_experiments.py`, which can run default experiments and save plots/metrics under `results/`. Use this only after completing the relevant TODOs.

# %%
# Example: run all default Gaussian experiments.
# !python run_experiments.py

# Example: run only behavior-cloning experiments.
# !python run_experiments.py --only behavior_cloning

# %% [markdown]
# ## Plot losses from log files
#
# The helper below parses lines containing `loss:` from saved logs and plots the resulting sequence.

# %%
import re
from pathlib import Path
import matplotlib.pyplot as plt

LOSS_RE = re.compile(r'loss:\s*([-+]?\d*\.?\d+(?:[eE][-+]?\d+)?)')

def parse_losses(log_path):
    log_path = Path(log_path)
    if not log_path.exists():
        raise FileNotFoundError(log_path)
    losses = []
    for line in log_path.read_text(errors='ignore').splitlines():
        match = LOSS_RE.search(line)
        if match:
            losses.append(float(match.group(1)))
    return losses

def plot_losses(log_path, title=None):
    losses = parse_losses(log_path)
    if not losses:
        raise ValueError(f'No loss entries found in {log_path}')
    plt.figure(figsize=(7, 4))
    plt.plot(range(len(losses)), losses)
    plt.xlabel('Logged training step')
    plt.ylabel('Loss')
    plt.title(title or str(log_path))
    plt.grid(True, alpha=0.3)
    plt.show()
    print(f'Parsed {len(losses)} losses from {log_path}')

# plot_losses('logs/bc_reacher_gaussian.log', 'BC Gaussian - Reacher')

# %%
# Uncomment any plot after the corresponding run cell has completed.
# plot_losses('logs/bc_reacher_gaussian.log', 'BC Gaussian - Reacher')
# plot_losses('logs/bc_pointmaze_gaussian.log', 'BC Gaussian - PointMaze')
# plot_losses('logs/dagger_reacher_gaussian.log', 'DAgger Gaussian - Reacher')
# plot_losses('logs/dagger_pointmaze_gaussian.log', 'DAgger Gaussian - PointMaze')
# plot_losses('logs/bc_pointmaze_autoregressive.log', 'BC Autoregressive - PointMaze')
# plot_losses('logs/dagger_pointmaze_autoregressive.log', 'DAgger Autoregressive - PointMaze')

# %% [markdown]
# ## Optional: package code for Canvas submission
#
# This creates a zip of your working directory. By default, it excludes expert data files and learned checkpoints to keep the submission small.

# %%
from pathlib import Path
import zipfile

submission_name = 'tcss590_hw1_submission.zip'
exclude_suffixes = {'.pyc', '.pkl', '.pth', '.pt'}
exclude_dirs = {'.git', '__pycache__', '.ipynb_checkpoints'}

with zipfile.ZipFile(submission_name, 'w', compression=zipfile.ZIP_DEFLATED) as zf:
    for path in Path('.').rglob('*'):
        if path.is_dir():
            continue
        parts = set(path.parts)
        if parts & exclude_dirs:
            continue
        if path.suffix in exclude_suffixes:
            continue
        if path.name == submission_name:
            continue
        zf.write(path, path.as_posix())

print(f'Created {submission_name}')
try:
    from google.colab import files
    files.download(submission_name)
except Exception:
    print('Download manually from the Colab file browser.')
